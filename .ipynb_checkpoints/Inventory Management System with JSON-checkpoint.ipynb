# %%
# Importing json, time, csv modules
import json
import time
import csv

# Initializing variable(s)
sale = ''

# Importing Inventory data from Records.json file
fd = open('Records.json','r')
js = fd.read()
fd.close()

# Converting String records to JSON/Dictionaries
record = json.loads(js)

# Displaying Menu
print("--------------------MENU---------------------\n")
for key in record.keys():
    print(key, "|",record[key]['Name'], "\t|",record[key]['Price'], "\t|",record[key]['Qn'])
print("\n---------------------------------------------")

# Taking Inputs from the user about their details and purchase
ui_name = str(input("Enter your name       : "))
ui_mail = str(input("Enter Mail ID         : "))
ui_ph   = str(input("Enter Phone No        : "))
ui_pr   = str(input("Enter product ID      : "))
ui_qn   = int(input("Enter Quantity        : "))

# If we're having equal or more quantity then the user wants
if (record[ui_pr]['Qn'] >= ui_qn):

    # Displaying Purchase details
    print("---------------------------------------------")
    print("---------------------------------------------")
    print("                     Bill                   \n")
    print("Name                  : ", record[ui_pr]["Name"])
    print("Price                 : ", record[ui_pr]["Price"], "Rs")
    print("Quantity              : ", ui_qn)
    print("---------------------------------------------")
    print("Billing amount        : ", ui_qn * record[ui_pr]["Price"], "Rs")
    print("---------------------------------------------")

    # Generating sales Details in CSV
    sale = ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+str(ui_qn * record[ui_pr]["Price"])+","+time.ctime()+"\n"

    # Updating Inventory in Dictionary
    record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
    
# If we're less quantity then the user wants
else:
    
    # Displaying info about the quantiy
    print("\n---------------------------------------------")
    print("Sorry, We're not having enough quanity of product in our Inventory.")
    print("We're only having " + str(record[ui_pr]['Qn']) + " quantity.")
    print("---------------------------------------------")
    
    ch = str(input("Press Y to purchase: "))
    
    # If user wants to purchase the whole quantity for that product
    if(ch == "Y" or ch == 'y'):

        # Displaying Purchase details
        print("---------------------------------------------")
        print("---------------------------------------------")
        print("                     Bill                   \n")
        print("---------------------------------------------")
        print("Name                  : ", record[ui_pr]["Name"])
        print("Price                 : ", record[ui_pr]["Price"], "Rs")
        print("Quantity              : ", record[ui_pr]['Qn'])
        print("---------------------------------------------")
        print("Billing               : ", record[ui_pr]['Qn'] * record[ui_pr]["Price"], "Rs")
        print("---------------------------------------------")

        
        # Generating sales Details in CSV
        sale = ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(record[ui_pr]['Qn'])+","+str(record[ui_pr]["Price"])+","+str(record[ui_pr]['Qn'] * record[ui_pr]["Price"])+","+time.ctime()+"\n"

        # Updating Inventory in Dictionary
        record[ui_pr]['Qn'] = 0
        
    # If user pressed anything except Y or y
    else:
        print("Thanks!")
        
# Converting Inventory Dictionary/JSON to String
js = json.dumps(record)

# Updating Inventory and Saving it to Records.json
fd = open('Records.json','w')
fd.write(js)
fd.close()

# Adding Sales details in text file
fd = open('Sales.txt','a')
fd.write(sale)
fd.close()

# Adding Sales details in CSV file
fd = open('Sales.csv','a')
fd.write(sale)
fd.close()

print("---------------------------------------------")
print("  Thanks for your order, Inventory Updated!  ")
print("---------------------------------------------")
# Out:
# --------------------MENU---------------------
#
# 1 | 5 Star 	| 10 	| 200
# 2 | Bar-One 	| 20 	| 100
# 3 | Candy 	| 2 	| 1000
# 4 | Chocolate Cake 	| 550 	| 35
# 5 | Blueberry Cake 	| 650 	| 35
#
# ---------------------------------------------
# Enter your name       : Dj
# Enter Mail ID         : dj69@mail.in
# Enter Phone No        : 8520369741
# Enter product ID      : 1
# Enter Quantity        : 5
# ---------------------------------------------
# ---------------------------------------------
#                      Bill
#
# Name                  :  5 Star
# Price                 :  10 Rs
# Quantity              :  5
# ---------------------------------------------
# Billing amount        :  50 Rs
# ---------------------------------------------
# ---------------------------------------------
#   Thanks for your order, Inventory Updated!
# ---------------------------------------------
